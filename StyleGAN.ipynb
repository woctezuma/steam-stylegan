# %% [markdown]
# # StyleGAN
#
# Reference: https://github.com/NVlabs/stylegan

# %% [markdown]
# ## Setting

# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive

mount_folder = '/content/gdrive'
drive.mount(mount_folder)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Go into the working directory

# %%
import os

app_folder = mount_folder + '/My Drive/'
os.chdir(app_folder)

# %% [markdown]
# ## Training a StyleGAN

# %% [markdown]
# Clone the latest version of my Github repository, so that the training is resumed from the last (manually specified)  checkpoint

# %%
# !rm -rf stylegan/
# !git clone https://github.com/woctezuma/stylegan.git
# Out:
# Cloning into 'stylegan'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 123 (delta 18), reused 19 (delta 9), pack-reused 95
# Receiving objects: 100% (123/123), 1.67 MiB | 3.88 MiB/s, done.
# Resolving deltas: 100% (58/58), done.

# %% [markdown]
# Preprocess (once) the image dataset

# %%
#!python stylegan/dataset_tool.py create_from_images datasets/stylegan '/content/gdrive/My Drive/data/128x128'

# %% [markdown]
# Training

# %%
# !python stylegan/train.py
# Out:
# Creating the run dir: results/00010-sgan-steam-1gpu
# Copying files to the run dir
# dnnlib: Running training.training_loop.training_loop() on localhost...
# Streaming data using training.dataset.TFRecordDataset...
# WARNING:tensorflow:From /content/gdrive/My Drive/stylegan/training/dataset.py:76: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Dataset shape = [3, 128, 128]
# Dynamic range = [0, 255]
# Label size    = 0
# Loading networks from "results/00009-sgan-steam-1gpu/network-snapshot-003524.pkl"...
#
# ...
